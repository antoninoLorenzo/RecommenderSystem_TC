# %%
import sqlite3

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from collections import Counter

# %%
offers_connection = sqlite3.connect('../datasets/offers_dataset.db')
offers_frame = pd.read_sql_query('''SELECT * FROM offers''', offers_connection)
offers_connection.close()
offers_frame
# Out:
#                                                   Name  \
# 0                                   Software Developer
# 1                            Junior Software Developer
# 2                                   Software Developer
# 3                                   Software Developer
# 4                            Senior Software Developer
# ..                                                 ...
# 587                           Python Software Engineer
# 588                                  Software Engineer
# 589                    R&D Labeling Principal Engineer
# 590  Workspace & Endpoint Deployment - System Engineer
# 591  Athonet - Elixir Software Engineer for Mobile ...
#
#                                            Description  \
# 0    Miniclip is a global leader in digital games w...
# 1    NETtoWORK, azienda italiana nata nel 2016, ope...
# 2    We are looking for talented and passionate peo...
# 3    ARESYS  is a R&D oriented company with nearly ...
# 4    Il/la Candidato/a dovrà padroneggiare: \n \n- ...
# ..                                                 ...
# 587  Now is an amazing time to join Nozomi Networks...
# 588  Who we are:At Mambu, we believe that banking a...
# 589  This is where you save and sustain lives  \n  ...
# 590  Intesa Sanpaolo è un gruppo bancario internazi...
# 591  Athonet - Elixir Software Engineer for Mobile ...
#
#                              Location
# 0                     Genova, Liguria
# 1                        17100 Savona
# 2                         55100 Lucca
# 3                  Matera, Basilicata
# 4                    Catania, Sicilia
# ..                                ...
# 587                 Milano, Lombardia
# 588        Provincia di Latina, Lazio
# 589           Medolla, Emilia-Romagna
# 590                 Milano, Lombardia
# 591  Cernusco sul Naviglio, Lombardia
#
# [592 rows x 3 columns]

# %% [markdown]
# **Presenza di Valori Nulli e Duplicati**
# Come è possibile vedere di seguito il dataset contiene valori nulli solo per la colonna Location, il che però è normale, in quanto non tutte le Offerte di lavoro sono in presenza, quindi le Location mancanti rappresentano il numero di Offerte di lavoro in Remote.
# Questa informazione è importante perchè in seguito ci sarà la necessità di rappresentare queste informazioni in modo omogeneo, in modo tale che un modello il cui scopo è raggruppare le Offerte (clustering, come proposto nell'Analisi del Problema) possa farlo in modo adeguato.

# %%
offers_frame.dropna(subset='Name', inplace=True)
offers_frame.drop_duplicates(inplace=True)
offers_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 586 entries, 0 to 591
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         586 non-null    object
#  1   Description  586 non-null    object
#  2   Location     542 non-null    object
# dtypes: object(3)
# memory usage: 18.3+ KB

# %% [markdown]
# # Data Preparation
# Per permettere il completo soddisfacimento dei requisiti, alcuni dati mancanti alle offerte dovranno essere aggiunti al dataset, tra cui:
# - RequiredSkills: le Competenze richieste da una Offerta
# - LocationType: il tipo di Location, se in remoto (Remote) o in sede (OnSite)
# - Languages: le lingue naturali necessarie per l'offerta di lavoro
# - Latitudine e Longitudine: per poter sfruttare la Location bisogna convertirla in Latitudine e Longitudine

# %% [markdown]
# ## Skill Extraction
# L'estrazione delle Competenze, o *skill*, dal dataset delle Offerte è eseguita estraendo le skill richieste dalle descrizioni delle Offerte, facendo riferimento al dataset delle Competenze.
# Di seguito viene mostrato il procedimento di estrazione.

# %%
from commons import (
    remove_symbols, 
    extract_symbols,
    translate_skills,
    REMOVAL
)

with sqlite3.connect('../datasets/skills_dataset.db') as skills_connection:
    skills_frame = pd.read_sql_query('SELECT * FROM skills', skills_connection)
    skills_frame.set_index('ID', inplace=True)

# %%
# Get Skill list
skills_list = [skill.lower() for skill in skills_frame['SKILL'].tolist()]

required_skills = [] 
for i, offer_description in enumerate(offers_frame.loc[:, 'Description']):
    desc = remove_symbols(offer_description, REMOVAL)
    offer_skills = extract_symbols(desc, skills_list)
    required_skills.append(translate_skills(offer_skills, skills_frame, to_id=True))
offers_frame.insert(len(offers_frame.columns), "RequiredSkills", required_skills)

# %% [markdown]
# ### Pulizia Offerte
#
# In seguito al processo di estrazione abbiamo notato che nel dataset erano presenti Offerte per cui non venivano specificate delle Competenze richieste, questo ci ha permesso di migliorare le procedure di estrazione e di identificare Competenze non contenute nel dataset; nonostante ciò sono rimaste delle Offerte che non richiedevano Competenze, in quanto effettivamente non venivano specificate nella descrizione, in questo caso sono state rimosse dal dataset in quanto il sistema Turing Careers durante il procedimento di creazione di una Offerta richiede a un Datore di Lavoro di inserire obbligatoriamente almeno una Competenza richiesta.
# Di seguito viene prima visualizzata la quantità di offerte inutilizzabili ed il viene effettuata la pulizia.

# %%
# Original dataset size
length_raw = len(offers_frame)

# Replace empty sets with numpy NaN 
offers_frame['RequiredSkills'] = offers_frame['RequiredSkills'].apply(lambda x: np.NaN if not x else x)

# Number of invalid offers
length_invalid = len(offers_frame[offers_frame['RequiredSkills'].isna()])

# Plot
plt.figure(figsize=(5,7))
offer_quality_plot = sns.barplot(hue=['Valid', 'Invalid'], y=[(length_raw-length_invalid), length_invalid], palette='viridis')
plt.ylabel('Number of Offers')
plt.title('Distribution of Valid and Invalid Offers')
plt.show()

# %%
# Remove offers with no required skills
offers_frame.dropna(subset='RequiredSkills', inplace=True)
offers_frame.reset_index(drop=True, inplace=True)

length_processed = len(offers_frame)
offers_frame
# Out:
#                                                   Name  \
# 0                                   Software Developer
# 1                            Junior Software Developer
# 2                                   Software Developer
# 3                                   Software Developer
# 4                            Senior Software Developer
# ..                                                 ...
# 477                        IT On-Site Support Engineer
# 478                           Python Software Engineer
# 479                                  Software Engineer
# 480  Workspace & Endpoint Deployment - System Engineer
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                                            Description  \
# 0    Miniclip is a global leader in digital games w...
# 1    NETtoWORK, azienda italiana nata nel 2016, ope...
# 2    We are looking for talented and passionate peo...
# 3    ARESYS  is a R&D oriented company with nearly ...
# 4    Il/la Candidato/a dovrà padroneggiare: \n \n- ...
# ..                                                 ...
# 477  IT On-Site Support EngineerFunctional area: In...
# 478  Now is an amazing time to join Nozomi Networks...
# 479  Who we are:At Mambu, we believe that banking a...
# 480  Intesa Sanpaolo è un gruppo bancario internazi...
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                              Location                        RequiredSkills
# 0                     Genova, Liguria                            {100, 101}
# 1                        17100 Savona                       {2, 6, 7, 8, 9}
# 2                         55100 Lucca                     {0, 3, 6, 44, 26}
# 3                  Matera, Basilicata                             {8, 9, 2}
# 4                    Catania, Sicilia  {0, 1, 99, 3, 6, 7, 104, 55, 57, 26}
# ..                                ...                                   ...
# 477                 Milano, Lombardia                                 {103}
# 478                 Milano, Lombardia                       {73, 89, 2, 30}
# 479        Provincia di Latina, Lazio                           {31, 30, 6}
# 480                 Milano, Lombardia                                 {103}
# 481  Cernusco sul Naviglio, Lombardia                                 {104}
#
# [482 rows x 4 columns]

# %% [markdown]
# ### Popolarità delle Skill

# %%
from commons import id_to_skill

# Count
out = []
skill_counts = Counter()
for skill_set in required_skills:
    if skill_set:
        sset = id_to_skill(skill_set, skills_frame)
        out.append(sset)
        for s in sset:
            skill_counts[s] += 1
sorted_counts = {skill: skill_counts[skill] for skill in sorted(skill_counts, key=skill_counts.get, reverse=True)}

# Plot
plt.figure(figsize=(10, 15))
sns.barplot(x=sorted_counts.values(), y=sorted_counts.keys())
plt.title("Distribution of Skills in the Dataset")
plt.xlabel("Count")
plt.ylabel("Skills")
plt.show()

# %% [markdown]
# ### Distribuzione del numero di skill richieste da ciascuna offerta
# Osserviamo la distribuzione del numero di skill richieste da ogni singola offerta nel tentativo di identificare eventuali outliers, offerte che richiedono un numero di skills particolarmente lontano dalla media.

# %%
skills_number = []
avg = 0

for sset in offers_frame.loc[:, "RequiredSkills"]:
    skills_number.append(len(sset))
    avg += len(sset)
avg /= len(offers_frame)
avg = int(avg)

plt.figure(figsize=(4, 6))
plt.title("Average amount of required skills")
plt.ylabel("Amount of required skills")
plt.xlabel("Average")
sns.boxplot(x=avg, y=skills_number)
plt.show()

# %% [markdown]
# Dal grafico si può notare la presenza di alcuni outliers, in particolare le offerte che richiedono un numero di skills maggiore di 12.
# Di seguito le offerte outliers:

# %%
tmp_frame = offers_frame["RequiredSkills"].apply(lambda sset: len(sset))
f = []

for v in tmp_frame:
    f.append(v > 12)

outliers = offers_frame.loc[f]
outliers
# Out:
#                                                   Name  \
# 27                                Full Stack Developer
# 107                                  Backend Developer
# 190                                 Frontend Developer
# 215                                 Backend developers
# 283                      Cloud Infrastructure Engineer
# 287                   (Azure) Cloud Solutions Engineer
# 291                                  Software Engineer
# 333                                  Software Engineer
# 365  Développeur Python senior - Jeux vidéos - CDI ...
# 431               MLOps Engineer - ML Platform (x/f/m)
#
#                                            Description  \
# 27   Role description:  \n \n- Develop new AI produ...
# 107  Se sei un/una Developer in gamba, con poca o m...
# 190  About Nexway  :Founded in 2002 Nexway has beco...
# 215  - Modelo retributivo a la carta- Horario flexi...
# 283  Job Description ‍Looking to be part of a team ...
# 287  If you like this offer, please send your CV me...
# 291  About this positionHere you will be part of on...
# 333  Who we areThe Workshop is a tech company that ...
# 365  Développeur Python - Jeux vidéos - CDI - Paris...
# 431  Job descriptionWhat you’ll doAt Doctolib, we'r...
#
#                              Location  \
# 27                               None
# 107                  Napoli, Campania
# 190                        Nîmes (30)
# 215                         En remoto
# 283                         En remoto
# 287      Valencia, Valencia provincia
# 291  18001 Granada, Granada provincia
# 333    28013 Madrid, Madrid provincia
# 365                        Paris (75)
# 431                        Paris (75)
#
#                                         RequiredSkills
# 27   {0, 2, 99, 100, 3, 73, 41, 78, 18, 19, 84, 52,...
# 107  {0, 1, 99, 100, 4, 73, 10, 44, 19, 21, 53, 24,...
# 190  {0, 1, 32, 99, 100, 4, 73, 41, 80, 21, 24, 25,...
# 215  {0, 1, 2, 99, 100, 3, 6, 4, 10, 14, 19, 52, 21...
# 283  {66, 2, 100, 5, 104, 73, 15, 80, 23, 30, 89, 9...
# 287  {2, 3, 100, 6, 9, 73, 11, 80, 18, 19, 89, 26, ...
# 291  {0, 2, 3, 100, 73, 41, 44, 50, 52, 21, 89, 59,...
# 333   {66, 2, 3, 4, 6, 73, 41, 44, 14, 80, 25, 61, 62}
# 365  {0, 65, 2, 1, 68, 99, 3, 7, 8, 6, 10, 41, 44, ...
# 431  {0, 66, 67, 2, 100, 34, 3, 4, 73, 80, 18, 54, ...

# %% [markdown]
# # Tipo di Location
# Per estrarre il tipo di Location dalle informazioni attualmente già presenti nel dataset,
# saranno interpretate come di tipo Remote tutte le offerte che non presentano una Location.

# %%
# Le Location En-Remoto devono essere trasformate in None
offers_frame["Location"] = offers_frame['Location'].apply(lambda location: np.NaN if location == 'En remoto' else location)

# %%
LOCATION_TYPES = {"Remote" : "Remote", "On Site" : "OnSite"}
locations_present = offers_frame["Location"].notna()
types = []

for is_present in locations_present:
    if is_present:
        types.append(LOCATION_TYPES["On Site"])
    else:
        types.append(LOCATION_TYPES["Remote"])

offers_frame.loc[:, "LocationType"] = types

offers_frame
# Out:
#                                                   Name  \
# 0                                   Software Developer
# 1                            Junior Software Developer
# 2                                   Software Developer
# 3                                   Software Developer
# 4                            Senior Software Developer
# ..                                                 ...
# 477                        IT On-Site Support Engineer
# 478                           Python Software Engineer
# 479                                  Software Engineer
# 480  Workspace & Endpoint Deployment - System Engineer
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                                            Description  \
# 0    Miniclip is a global leader in digital games w...
# 1    NETtoWORK, azienda italiana nata nel 2016, ope...
# 2    We are looking for talented and passionate peo...
# 3    ARESYS  is a R&D oriented company with nearly ...
# 4    Il/la Candidato/a dovrà padroneggiare: \n \n- ...
# ..                                                 ...
# 477  IT On-Site Support EngineerFunctional area: In...
# 478  Now is an amazing time to join Nozomi Networks...
# 479  Who we are:At Mambu, we believe that banking a...
# 480  Intesa Sanpaolo è un gruppo bancario internazi...
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                              Location                        RequiredSkills  \
# 0                     Genova, Liguria                            {100, 101}
# 1                        17100 Savona                       {2, 6, 7, 8, 9}
# 2                         55100 Lucca                     {0, 3, 6, 44, 26}
# 3                  Matera, Basilicata                             {8, 9, 2}
# 4                    Catania, Sicilia  {0, 1, 99, 3, 6, 7, 104, 55, 57, 26}
# ..                                ...                                   ...
# 477                 Milano, Lombardia                                 {103}
# 478                 Milano, Lombardia                       {73, 89, 2, 30}
# 479        Provincia di Latina, Lazio                           {31, 30, 6}
# 480                 Milano, Lombardia                                 {103}
# 481  Cernusco sul Naviglio, Lombardia                                 {104}
#
#     LocationType
# 0         OnSite
# 1         OnSite
# 2         OnSite
# 3         OnSite
# 4         OnSite
# ..           ...
# 477       OnSite
# 478       OnSite
# 479       OnSite
# 480       OnSite
# 481       OnSite
#
# [482 rows x 5 columns]

# %% [markdown]
# # Lingue Richiesti
# Per dedurre quali lingue parlate sono richieste da una data offerta di lavoro, viene utilizzato il modulo langdetect per identificare la lingua in cui è stata scritta la descrizione dell'offerta stessa, e successivamente tramite una ricerca all'interno del testo della descrizione per menzioni di ulteriori lingue.

# %%
from langdetect import detect
from string import punctuation
offers_langs = []
remove_map = {p:'' for p in punctuation}

eqs = {'it' : ('italiano', 'italian', 'italien', 'italiano'), 
       'en' : ('inglese', 'english', 'anglais', 'inglés'),
       'fr' : ('francese', 'french', 'français', 'francés'),
       'es' : ('spagnolo', 'spanish', 'espagnol', 'español')}

supported_langs = [x for v in eqs.values() for x in v]


for i, desc in enumerate(offers_frame.Description):
    lang = detect(desc)
    
    try:
        lang = eqs[lang][0]
    except KeyError:
        print(f'offer {i} unsupported "{lang}" detected')
        lang = None
    
    desc = remove_symbols(desc, remove_map)
    found = extract_symbols(desc, supported_langs)
    
    found = list(found)
    for i, l in enumerate(found):
        for e in eqs.values():
            if l in e:
                found[i] = e[0]
                break
    
    found = set(found)
    
    if lang is not None:
        found.add(lang)
    offers_langs.append(found)
    
offers_frame.loc[:, "Languages"] = offers_langs

offers_frame
# Out:
#                                                   Name  \
# 0                                   Software Developer
# 1                            Junior Software Developer
# 2                                   Software Developer
# 3                                   Software Developer
# 4                            Senior Software Developer
# ..                                                 ...
# 477                        IT On-Site Support Engineer
# 478                           Python Software Engineer
# 479                                  Software Engineer
# 480  Workspace & Endpoint Deployment - System Engineer
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                                            Description  \
# 0    Miniclip is a global leader in digital games w...
# 1    NETtoWORK, azienda italiana nata nel 2016, ope...
# 2    We are looking for talented and passionate peo...
# 3    ARESYS  is a R&D oriented company with nearly ...
# 4    Il/la Candidato/a dovrà padroneggiare: \n \n- ...
# ..                                                 ...
# 477  IT On-Site Support EngineerFunctional area: In...
# 478  Now is an amazing time to join Nozomi Networks...
# 479  Who we are:At Mambu, we believe that banking a...
# 480  Intesa Sanpaolo è un gruppo bancario internazi...
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                              Location                        RequiredSkills  \
# 0                     Genova, Liguria                            {100, 101}
# 1                        17100 Savona                       {2, 6, 7, 8, 9}
# 2                         55100 Lucca                     {0, 3, 6, 44, 26}
# 3                  Matera, Basilicata                             {8, 9, 2}
# 4                    Catania, Sicilia  {0, 1, 99, 3, 6, 7, 104, 55, 57, 26}
# ..                                ...                                   ...
# 477                 Milano, Lombardia                                 {103}
# 478                 Milano, Lombardia                       {73, 89, 2, 30}
# 479        Provincia di Latina, Lazio                           {31, 30, 6}
# 480                 Milano, Lombardia                                 {103}
# 481  Cernusco sul Naviglio, Lombardia                                 {104}
#
#     LocationType            Languages
# 0         OnSite            {inglese}
# 1         OnSite           {italiano}
# 2         OnSite            {inglese}
# 3         OnSite            {inglese}
# 4         OnSite           {italiano}
# ..           ...                  ...
# 477       OnSite  {inglese, italiano}
# 478       OnSite            {inglese}
# 479       OnSite            {inglese}
# 480       OnSite  {inglese, italiano}
# 481       OnSite  {inglese, italiano}
#
# [482 rows x 6 columns]

# %% [markdown]
# ## Distribuzione delle Lingue Richieste
#
# Per verificare che il dataset fornisca una buona rappresentazione della realtà è sempre buona norma verificare la distribuzione dei dati, in alcuni casi, per la natura del problema, è impossibile avere un campionario bilanciato e bisogna ricorrere a tecniche *estreme* per ottenere un dataset la cui distribuzione non generi bias nei modelli di Machine Learning applicati, nel nostro caso invece basta ritornare alla fase di collezione dei dati; per questo motivo di seguito viene mostrata la distribuzione delle Lingue Richieste da una offerta.

# %%
# The count is executed given the assumption that the Required Languages can be Italian or English
language_counter = Counter()
language_number_counter = Counter()
for offer_languages in offers_frame.loc[:, 'Languages']:
    for l in set(offer_languages):
        language_counter[l] += 1
            
    language_number_counter[len(offer_languages)] += 1
    
# Pie chart for Required Languages Distribution
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.title('Required Languages Distribution')
plt.pie(language_counter.values(), labels=language_counter.keys(), autopct='%0.f%%')

# Bar chart for Amount Of Required Languages Distribution
plt.subplot(1, 2, 2)
plt.title('Amount Of Required Languages Distribution')
plt.bar(['1', '2', '3', '4'], language_number_counter.values())

plt.tight_layout()  # To prevent overlapping of subplots
plt.show()

# %% [markdown]
# # Latitudine e Longitudine delle Location

# %%
from commons import get_coordinates

# Compute Latitude and Longitude for each Offer 
offers_frame['Latitude'] = 0.0
offers_frame['Longitude'] = 0.0

for index, row in offers_frame.iterrows():
    try:
        if row['Location']:
            lat, lon = get_coordinates(row['Location']).values()
            offers_frame.loc[index, 'Latitude'] = lat
            offers_frame.loc[index, 'Longitude'] = lon
    except Exception:
        pass
 
offers_frame
# Out:
#                                                   Name  \
# 0                                   Software Developer
# 1                            Junior Software Developer
# 2                                   Software Developer
# 3                                   Software Developer
# 4                            Senior Software Developer
# ..                                                 ...
# 477                        IT On-Site Support Engineer
# 478                           Python Software Engineer
# 479                                  Software Engineer
# 480  Workspace & Endpoint Deployment - System Engineer
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                                            Description  \
# 0    Miniclip is a global leader in digital games w...
# 1    NETtoWORK, azienda italiana nata nel 2016, ope...
# 2    We are looking for talented and passionate peo...
# 3    ARESYS  is a R&D oriented company with nearly ...
# 4    Il/la Candidato/a dovrà padroneggiare: \n \n- ...
# ..                                                 ...
# 477  IT On-Site Support EngineerFunctional area: In...
# 478  Now is an amazing time to join Nozomi Networks...
# 479  Who we are:At Mambu, we believe that banking a...
# 480  Intesa Sanpaolo è un gruppo bancario internazi...
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                              Location                        RequiredSkills  \
# 0                     Genova, Liguria                            {100, 101}
# 1                        17100 Savona                       {2, 6, 7, 8, 9}
# 2                         55100 Lucca                     {0, 3, 6, 44, 26}
# 3                  Matera, Basilicata                             {8, 9, 2}
# 4                    Catania, Sicilia  {0, 1, 99, 3, 6, 7, 104, 55, 57, 26}
# ..                                ...                                   ...
# 477                 Milano, Lombardia                                 {103}
# 478                 Milano, Lombardia                       {73, 89, 2, 30}
# 479        Provincia di Latina, Lazio                           {31, 30, 6}
# 480                 Milano, Lombardia                                 {103}
# 481  Cernusco sul Naviglio, Lombardia                                 {104}
#
#     LocationType            Languages   Latitude  Longitude
# 0         OnSite            {inglese}  44.405650   8.946256
# 1         OnSite           {italiano}  44.342550   8.429389
# 2         OnSite            {inglese}  43.842920  10.502698
# 3         OnSite            {inglese}  40.666379  16.604320
# 4         OnSite           {italiano}  37.507877  15.083030
# ..           ...                  ...        ...        ...
# 477       OnSite  {inglese, italiano}  45.464204   9.189982
# 478       OnSite            {inglese}  45.464204   9.189982
# 479       OnSite            {inglese}  41.408748  13.081790
# 480       OnSite  {inglese, italiano}  45.464204   9.189982
# 481       OnSite  {inglese, italiano}  45.524980   9.332959
#
# [482 rows x 8 columns]

# %%
import folium
EUROPE = [51.5074, -0.1278]

offers_map = folium.Map(location=EUROPE, zoom_start=4)

for index, row in offers_frame.iterrows():
    if row['LocationType'] != 'Remote':
        tooltip_text = f'<b>{row["Name"]}</b>'
        folium.Marker(
            [row['Latitude'], row['Longitude']], 
            tooltip=row['Location'],
            popup=tooltip_text
        ).add_to(offers_map)

offers_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f58ca692be8dfd9249db27c38f34e183 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f58ca692be8dfd9249db27c38f34e183&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f58ca692be8dfd9249db27c38f34e183 = L.map(
#                 &quot;map_f58ca692be8dfd9249db27c38f34e183&quot;,
#                 {
#                     center: [51.5074, -0.1278],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3c5415b68fcb53fffb1ee2890a8b536 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f3c5415b68fcb53fffb1ee2890a8b536.addTo(map_f58ca692be8dfd9249db27c38f34e183);
#
#
#             var marker_9a93e1884065f2f302d7bb3ad824e6c2 = L.marker(
#                 [44.4056499, 8.946256],
#                 {}
#             ).addTo(map_f58ca692be8dfd9249db27c38f34e183);
#
#
#         var popup_9cd93346b99fff63c9222029edce6eda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_095d986dc4a1b5a7d4fc3291776c2673 = $(`&lt;div id=&quot;html_095d986dc4a1b5a7d4fc3291776c2673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Software Developer&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_9cd93346b99fff63c9222029edce6eda.setContent(html_095d986dc4a1b5a7d4fc3291776c2673);
#
#
#
#         marker_9a93e1884065f2f302d7bb3ad824e6c2.bindPopup(popup_9cd93346b99fff63c9222029edce6eda)
#         ;
#
#
#
#
#             marker_9a93e1884065f2f302d7bb3ad824e6c2.bindTooltip(
#                 `&lt;div&gt;
#                      Genova, Liguria
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_18cb60ce4636368700bae1c8f8eadaad = L.marker(
#                 [44.3425496, 8.4293891],
#                 {}
#             ).addTo(map_f58ca692be8dfd9249db27c38f34e183);
#
#
#         var popup_bb2980740fad61009407ad2d14948dda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_508f267ba31c3dd44893adc78ef2fbda = $(`&lt;div id=&quot;html_508f267ba31c3dd44893adc78ef2fbda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Junior Software Developer&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_bb2980740fad61009407ad2d14948dda.setContent(html_508f267ba31c3dd44893adc78ef2fbda);
#
#
#
#         marker_18cb60ce4636368700bae1c8f8eadaad.bindPopup(popup_bb2980740fad61009407ad2d14948dda)
#         ;
#
#
#
#
#             marker_18cb60ce4636368700bae1c8f8eadaad.bindTooltip(
#                 `&lt;div&gt;
#                      17100 Savona
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_122b9b1e6b486d468b4fb78923edee81 = L.marker(
#                 [43.8429197, 10.5026977],
#                 {}
#             ).addTo(map_f58ca692be8dfd9249db27c38f34e183);
#
#
#         var popup_ea519622cf8723b8fee27a80eb6121e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e6ffaefaecedd1a934b7d9ce57b5650 = $(`&lt;div id=&quot;html_6e6ffaefaecedd1a934b7d9ce57b5650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Software Developer&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_ea519622cf8723b8fee27a80eb6121e5.setContent(html_6e6ffaefaecedd1a934b7d9ce57b5650);
#
#
#
#         marker_122b9b1e6b486d468b4fb78923edee81.bindPopup(popup_ea519622cf8723b8fee27a80eb6121e5)
#         ;
#
#
#
#
#             marker_122b9b1e6b486d468b4fb78923edee81.bindTooltip(
#                 `&lt;div&gt;
#                      55100 Lucca
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf1ba5a4ca108010e63d4b38666688bc = L.marker(
#                 [40.666379, 16.6043199],
#                 {}
#             ).addTo(map_f58ca692be8dfd9249db27c38f34e183);
#
#
#         var popup_59b91051d7e0d2a8af244eab9bae1dda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e396cffd1d78a438f8ca53c75726af1d = $(`&lt;div id=&quot;html_e396cffd1d78a438f8ca53c75726af1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Software Developer&lt;/b&gt;&lt;/div&gt;`)[0];
#                 popup_59b91051d7e0d2a8af244eab9bae1dda.setContent(html_e396cffd1d78a438f8ca53c75726af1d);
#
#
#
#         marker_cf1ba5a4ca108010e63d4b38666688bc.bindPopup(popup_59b91051d7e0d2a8af244eab9bae1dda)
#         ;
#
#
#
#
#             marker_cf1ba5a4ca108010e63d4b38666688bc.bindTooltip(
#                 `&lt;div&gt;
#                      Matera, Basilicata
#                  &lt;/div&gt;`,
#                 {&

# %% [markdown]
# # Export
# Di seguito viene esportato il dataset aggiornato per poter lavorare in modo più veloce nella fase di modeling.

# %%
# Convert RequiredSkills and Languages
def set_to_string(item_set):
    return ', '.join(map(str, item_set))

offers_frame['RequiredSkills'] = offers_frame['RequiredSkills'].apply(set_to_string)
offers_frame['Languages'] = offers_frame['Languages'].apply(set_to_string)

offers_frame
# Out:
#                                                   Name  \
# 0                                   Software Developer
# 1                            Junior Software Developer
# 2                                   Software Developer
# 3                                   Software Developer
# 4                            Senior Software Developer
# ..                                                 ...
# 477                        IT On-Site Support Engineer
# 478                           Python Software Engineer
# 479                                  Software Engineer
# 480  Workspace & Endpoint Deployment - System Engineer
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                                            Description  \
# 0    Miniclip is a global leader in digital games w...
# 1    NETtoWORK, azienda italiana nata nel 2016, ope...
# 2    We are looking for talented and passionate peo...
# 3    ARESYS  is a R&D oriented company with nearly ...
# 4    Il/la Candidato/a dovrà padroneggiare: \n \n- ...
# ..                                                 ...
# 477  IT On-Site Support EngineerFunctional area: In...
# 478  Now is an amazing time to join Nozomi Networks...
# 479  Who we are:At Mambu, we believe that banking a...
# 480  Intesa Sanpaolo è un gruppo bancario internazi...
# 481  Athonet - Elixir Software Engineer for Mobile ...
#
#                              Location                      RequiredSkills  \
# 0                     Genova, Liguria                            100, 101
# 1                        17100 Savona                       2, 6, 7, 8, 9
# 2                         55100 Lucca                     0, 3, 6, 44, 26
# 3                  Matera, Basilicata                             8, 9, 2
# 4                    Catania, Sicilia  0, 1, 99, 3, 6, 7, 104, 55, 57, 26
# ..                                ...                                 ...
# 477                 Milano, Lombardia                                 103
# 478                 Milano, Lombardia                       73, 89, 2, 30
# 479        Provincia di Latina, Lazio                           31, 30, 6
# 480                 Milano, Lombardia                                 103
# 481  Cernusco sul Naviglio, Lombardia                                 104
#
#     LocationType          Languages   Latitude  Longitude
# 0         OnSite            inglese  44.405650   8.946256
# 1         OnSite           italiano  44.342550   8.429389
# 2         OnSite            inglese  43.842920  10.502698
# 3         OnSite            inglese  40.666379  16.604320
# 4         OnSite           italiano  37.507877  15.083030
# ..           ...                ...        ...        ...
# 477       OnSite  inglese, italiano  45.464204   9.189982
# 478       OnSite            inglese  45.464204   9.189982
# 479       OnSite            inglese  41.408748  13.081790
# 480       OnSite  inglese, italiano  45.464204   9.189982
# 481       OnSite  inglese, italiano  45.524980   9.332959
#
# [482 rows x 8 columns]

# %%
# Persist
with sqlite3.connect('../datasets/offers_full.db') as export_conn:
    export_curs = export_conn.cursor()
    export_conn.execute(
        '''
        CREATE TABLE IF NOT EXISTS offers (
            Name TEXT,
            Description TEXT,
            Location TEXT,
            RequiredSkills TEXT,
            LocationType TEXT,
            Languages TEXT,
            Latitude REAL,
            Longitude REAL
        )
        '''
    )
    
    export_conn.commit()
    
    offers_frame.to_sql('offers', export_conn, if_exists='append', index=False)
