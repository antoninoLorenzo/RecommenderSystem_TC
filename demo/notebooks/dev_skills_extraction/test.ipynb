# %%
import sqlite3

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
with sqlite3.connect('../../datasets/dev-bio_dataset.db') as dev_conn:
    developers_frame = pd.read_sql_query('SELECT BIO FROM developer_bio', dev_conn)
developers_frame
# Out:
#                                                    BIO
# 0    I am a Senior Cybersecurity/Information Securi...
# 1    I’m a Salesforce Certified Sales Cloud, Servic...
# 2    Hi, I'm Rizwan, a dedicated Data Scientist wit...
# 3    I offer assistance in a range of web developme...
# 4    ✅ 16+ Years of WordPress Experience. \n✅ 5+ Ye...
# ..                                                 ...
# 443  With 8+ years of experience working in Upwork ...
# 444  ✅ 𝟭𝟱+ 𝘆𝗲𝗮𝗿𝘀 𝗲𝘅𝗽𝗲𝗿𝗶𝗲𝗻𝗰𝗲𝗱 𝗠𝗶𝗰𝗿𝗼𝘀𝗼𝗳𝘁 𝗔𝘇𝘂𝗿𝗲 | 𝗢𝗳𝗳𝗶...
# 445  Welcome to the nexus of modern software develo...
# 446  With a remarkable 25-year career, I'm a season...
# 447  Over two decades of experience in the software...
#
# [448 rows x 1 columns]

# %%
from string import punctuation
with sqlite3.connect('../../datasets/skills_dataset.db') as skills_connection:
    skills_frame = pd.read_sql_query('SELECT * FROM skills', skills_connection)
    skills_frame.set_index('ID', inplace=True)

# %%
def remove_symbols(description: str, remove_map: dict) -> str:
    """
    """
    for old, new in remove_map.items():
        description = description.replace(old, new)
    return description.lower()


def extract_symbols(description: str, available_symbols: list) -> set:
    s = set()
    prev = ''
    for word in description.split():
        if word in available_symbols:
            s.add(word)
        elif f'{prev} {word}' in available_symbols:
            s.add(f'{prev} {word}')  
        prev = word
    return s 

def translate_skills(skills: set, toId = False) -> set:
    if toId:
        return skill_to_id(skills)
    else:
        return id_to_skill(skills)

def id_to_skill(skills: set[int]) -> set[str]:
    out = set()
    for skill in skills:
        out.add(skills_frame.loc[skill, 'SKILL'])
    
    return out

def skill_to_id(skills: set[str]) -> set[int]:
    out = set()
    for skill in skills:
        out.add(
            list(
                skills_frame.loc[
                    skills_frame['SKILL'].apply(lambda val: val.lower()) == skill.lower()
                ].index
            )[0]
        )
    
    return out

# Symbols to remove
punct = [p for p in punctuation]
punct.remove('+')
punct.remove('#')
# punct.remove('.')

removal = {p: ' ' for p in punct}
removal['\n'] = ''
removal['/'] = ' '
removal['('] = ' '
removal[')'] = ' '
removal[','] = ' '
removal['>'] = ' '
removal['.'] = ' .'

# %%
# Get Skill list
skills_list = [skill.lower() for skill in skills_frame['SKILL'].tolist()]

# Extract skills from descriptions and add new column
required_skills = [] 
for i, offer_description in enumerate(developers_frame.loc[:, 'BIO']):
    desc = remove_symbols(offer_description, removal)
    offer_skills = extract_symbols(desc, skills_list)
    required_skills.append(translate_skills(offer_skills, toId=True))

# %%
from collections import Counter
out = []
for skill_set in required_skills:
    if skill_set:
       out.append(id_to_skill(skill_set))
# Out:
# [{'JavaScript'},
#  {'PyTorch', 'TensorFlow'},
#  {'WordPress'},
#  {'Linux', 'Bash'},
#  {'Azure',
#   'CSS',
#   'Flutter',
#   'HTML',
#   'Laravel',
#   'Linux',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'jQuery'},
#  {'Python'},
#  {'WordPress'},
#  {'PHP', 'WordPress', 'CSS'},
#  {'C++', 'Java', 'Flask', 'Python', 'Linux', 'C'},
#  {'WordPress'},
#  {'AWS',
#   'Angular',
#   'Dynamodb',
#   'Java',
#   'JavaScript',
#   'Kubernetes',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'Terraform',
#   'TypeScript'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'Bash',
#   'Docker',
#   'Google Cloud',
#   'Heroku',
#   'Linux',
#   'PowerShell',
#   'Terraform',
#   'WordPress'},
#  {'React', 'React Native'},
#  {'AngularJS',
#   'CSS',
#   'HTML',
#   'Heroku',
#   'Java',
#   'JavaScript',
#   'SQL',
#   'Spring',
#   'WordPress',
#   'jQuery'},
#  {'AWS', 'Terraform', 'AngularJS', 'Cloudflare', 'Linux', 'Docker'},
#  {'HTML', 'WordPress'},
#  {'PHP', 'MariaDB', 'PostgreSQL', 'SQL', 'MySQL', 'Linux'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'Docker',
#   'Google Cloud',
#   'Kubernetes',
#   'Linux',
#   'Terraform'},
#  {'PHP', 'CSS', 'MySQL', 'WordPress', 'HTML'},
#  {'.NET',
#   'C#',
#   'Firebase',
#   'JavaScript',
#   'Linux',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'Python',
#   'SQL',
#   'TypeScript',
#   'Visual Studio'},
#  {'Go'},
#  {'AWS'},
#  {'Azure'},
#  {'Azure', 'SQL'},
#  {'WordPress'},
#  {'Oracle'},
#  {'React', 'Python', 'React Native'},
#  {'Linux'},
#  {'SQL', 'Python', 'Firebase'},
#  {'WordPress'},
#  {'AWS', 'Google Cloud', 'WordPress', 'Azure', 'Swift'},
#  {'Go', 'Linux'},
#  {'WordPress'},
#  {'Java', 'iOS', 'Flask', 'Flutter', 'Pandas', 'NumPy', 'Python', 'Swift', 'C'},
#  {'AWS',
#   'Azure',
#   'Flask',
#   'Google Cloud',
#   'Opencv',
#   'PyTorch',
#   'Python',
#   'React',
#   'TensorFlow'},
#  {'Azure', 'iOS'},
#  {'Azure', 'AWS'},
#  {'WordPress'},
#  {'Go'},
#  {'Go', 'WordPress', 'iOS'},
#  {'WordPress'},
#  {'SQL', 'Flask', 'Azure', 'Pandas', 'NumPy', 'Python'},
#  {'Java', 'Python', 'C#'},
#  {'C++', 'WordPress', 'Java', 'Python', 'C'},
#  {'WordPress'},
#  {'WordPress', 'Oracle'},
#  {'JavaScript', 'SQL'},
#  {'AWS',
#   'Azure',
#   'C#',
#   'C++',
#   'Docker',
#   'Git',
#   'JavaScript',
#   'Kubernetes',
#   'Linux',
#   'OpenGL',
#   'PowerShell',
#   'TypeScript'},
#  {'CSS',
#   'Express',
#   'Flutter',
#   'Google Cloud',
#   'HTML',
#   'JavaScript',
#   'Laravel',
#   'MySQL',
#   'PHP',
#   'React',
#   'SQLite',
#   'WordPress',
#   'jQuery'},
#  {'MySQL', 'SQL', 'Oracle'},
#  {'Go', 'SQL'},
#  {'AWS',
#   'Azure',
#   'Cloudflare',
#   'Linux',
#   'MariaDB',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'WordPress'},
#  {'HTML', 'WordPress', 'CSS'},
#  {'C#',
#   'Express',
#   'Firebase',
#   'JavaScript',
#   'MongoDB',
#   'Opencv',
#   'PostgreSQL',
#   'React',
#   'TypeScript',
#   'WordPress',
#   'iOS'},
#  {'Python', 'MySQL', 'AWS', 'MongoDB'},
#  {'AWS', 'Azure', 'Flask', 'Django'},
#  {'C'},
#  {'MySQL', 'SQL', 'Azure'},
#  {'Firebase', 'Go', 'WordPress'},
#  {'WordPress'},
#  {'SQL'},
#  {'JavaScript', 'CSS', 'HTML'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'Laravel', 'React', 'HTML'},
#  {'PHP', 'JavaScript', 'Go'},
#  {'WordPress'},
#  {'Python', 'Pandas'},
#  {'JavaScript', 'Python', 'Flutter'},
#  {'AWS',
#   'Azure',
#   'Cloudflare',
#   'Google Cloud',
#   'HTML',
#   'Linux',
#   'MySQL',
#   'PHP',
#   'Python',
#   'Swift',
#   'WordPress'},
#  {'Go'},
#  {'Opencv', 'Python', 'TensorFlow', 'PyTorch'},
#  {'AWS', 'Terraform'},
#  {'PHP', 'CSS', 'JavaScript', 'MySQL', 'WordPress', 'Cloudflare', 'HTML'},
#  {'Python', 'CSS', 'Django', 'FastAPI', 'React', 'Flask', 'HTML'},
#  {'iOS'},
#  {'Azure', 'PowerShell', 'Terraform'},
#  {'WordPress'},
#  {'AWS',
#   'Angular',
#   'Azure',
#   'Docker',
#   'Flutter',
#   'Google Cloud',
#   'JavaScript',
#   'Kubernetes',
#   'React',
#   'React Native',
#   'Swift',
#   'Terraform',
#   'iOS'},
#  {'iOS'},
#  {'JavaScript'},
#  {'Python'},
#  {'AWS', 'CSS', 'JavaScript', 'WordPress', 'HTML'},
#  {'AWS',
#   'Azure',
#   'Docker',
#   'Google Cloud',
#   'Linux',
#   'MariaDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'PowerShell',
#   'SQL',
#   'VMware',
#   'WordPress'},
#  {'AWS',
#   'Angular',
#   'Express',
#   'Git',
#   'JavaScript',
#   'Laravel',
#   'Linux',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'React',
#   'React Native',
#   'jQuery'},
#  {'Linux'},
#  {'WordPress'},
#  {'JavaScript', 'Python', 'CSS', 'HTML'},
#  {'.NET',
#   'AWS',
#   'Azure',
#   'C#',
#   'C++',
#   'Docker',
#   'Java',
#   'JavaScript',
#   'Linux',
#   'PHP',
#   'SQL',
#   'VMware'},
#  {'VMware', 'iOS', 'Linux'},
#  {'PHP', 'Laravel', 'Composer'},
#  {'VMware', 'Azure'},
#  {'CSS', 'JavaScript', 'WordPress', 'iOS', 'HTML'},
#  {'WordPress'},
#  {'AWS',
#   'Ansible',
#   'Cloudflare',
#   'Google Cloud',
#   'Linux',
#   'MySQL',
#   'PHP',
#   'WordPress'},
#  {'AWS',
#   'Azure',
#   'Docker',
#   'Flask',
#   'Git',
#   'Go',
#   'JavaScript',
#   'Linux',
#   'Python',
#   'React'},
#  {'PHP', 'MariaDB', 'PostgreSQL', 'MySQL', 'Redis', 'Linux'},
#  {'WordPress'},
#  {'HTML'},
#  {'JavaScript', 'WordPress', 'CSS'},
#  {'AWS',
#   'Angular',
#   'Django',
#   'Dynamodb',
#   'Flask',
#   'JavaScript',
#   'MariaDB',
#   'MongoDB',
#   'MySQL',
#   'PostgreSQL',
#   'Python',
#   'React',
#   'TypeScript'},
#  {'JavaScript', 'SQL', 'HTML'},
#  {'AWS',
#   'Angular',
#   'Azure',
#   'CSS',
#   'Git',
#   'Google Cloud',
#   'HTML',
#   'JavaScript',
#   'Laravel',
#   'Linux',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'React',
#   'WordPress',
#   'jQuery'},
#  {'Azure', 'Kubernetes', 'Docker'},
#  {'AWS'},
#  {'AWS',
#   'CSS',
#   'Django',
#   'Flask',
#   'Git',
#   'HTML',
#   'JavaScript',
#   'MariaDB',
#   'MySQL',
#   'Pandas',
#   'PostgreSQL',
#   'Python'},
#  {'WordPress', 'CSS'},
#  {'PHP', 'CSS', 'WordPress', 'SQL', 'HTML'},
#  {'JavaScript', '.NET', 'Oracle', 'iOS', 'SQL', 'Express', 'HTML', 'C#'},
#  {'AWS',
#   'Ansible',
#   'Docker',
#   'Git',
#   'Kubernetes',
#   'MongoDB',
#   'MySQL',
#   'Oracle',
#   'SQL',
#   'WordPress'},
#  {'jQuery', 'HTML', 'WordPress'},
#  {'WordPress'},
#  {'.NET',
#   'AngularJS',
#   'C#',
#   'JavaScript',
#   'React',
#   'React Native',
#   'SQL',
#   'jQuery'},
#  {'AWS', 'Google Cloud', 'WordPress', 'Cloudflare', 'Linux'},
#  {'Python', 'SQL', 'AWS'},
#  {'Oracle', 'Java', 'SQL', 'MySQL', 'Spring', 'Linux'},
#  {'Composer', 'HTML', 'WordPress'},
#  {'AWS',
#   'Docker',
#   'Git',
#   'Google Cloud',
#   'JavaScript',
#   'Laravel',
#   'Linux',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'SQL',
#   'WordPress',
#   'jQuery'},
#  {'AWS',
#   'Azure',
#   'Docker',
#   'Git',
#   'Google Cloud',
#   'Kubernetes',
#   'Laravel',
#   'Linux',
#   'MySQL',
#   'WordPress'},
#  {'WordPress'},
#  {'AWS',
#   'CSS',
#   'Django',
#   'Flask',
#   'Flutter',
#   'Google Cloud',
#   'HTML',
#   'MySQL',
#   'NumPy',
#   'Pandas',
#   'Python'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'MySQL', 'WordPress', 'HTML'},
#  {'Linux', 'AWS'},
#  {'VMware'},
#  {'WordPress'},
#  {'HTML', 'WordPress'},
#  {'AWS',
#   'Bash',
#   'Docker',
#   'Kubernetes',
#   'Linux',
#   'MariaDB',
#   'MySQL',
#   'PHP',
#   'Python',
#   'Terraform'},
#  {'CSS',
#   'Git',
#   'HTML',
#   'JavaScript',
#   'Laravel',
#   'Linux',
#   'MySQL',
#   'PHP',
#   'SQL',
#   'WordPress',
#   'jQuery'},
#  {'Django', 'MySQL', 'PyTorch', 'TensorFlow', 'Pandas', 'Python'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'C#',
#   'Cloudflare',
#   'Django',
#   'Docker',
#   'Express',
#   'Firebase',
#   'Flask',
#   'HTML',
#   'Kubernetes',
#   'Linux',
#   'MongoDB',
#   'MySQL',
#   'Pandas',
#   'PostgreSQL',
#   'Python',
#   'React',
#   'Swift',
#   'iOS'},
#  {'SQL'},
#  {'AWS',
#   'Azure',
#   'Bash',
#   'C',
#   'C++',
#   'Cloudflare',
#   'Docker',
#   'Elasticsearch',
#   'JavaScript',
#   'Kubernetes',
#   'MongoDB',
#   'MySQL',
#   'PostgreSQL',
#   'Python',
#   'Terraform'},
#  {'CSS'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'Docker',
#   'Linux',
#   'MariaDB',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'VMware',
#   'WordPress'},
#  {'CSS', 'jQuery', 'Composer', 'WordPress', 'HTML'},
#  {'Go'},
#  {'AWS',
#   'Docker',
#   'Dynamodb',
#   'HTML',
#   'Linux',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'Python',
#   'VMware',
#   'WordPress'},
#  {'WordPress', 'AWS'},
#  {'HTML', 'Go'},
#  {'AWS', 'Google Cloud', 'PostgreSQL', 'SQL', 'Azure', 'MySQL'},
#  {'Python', 'SQL'},
#  {'MariaDB', 'WordPress', 'Bash', 'Linux', 'Docker'},
#  {'AWS', 'Go', 'WordPress', 'Cloudflare', 'Linux'},
#  {'PHP', 'CSS', 'Angular', 'JavaScript', 'MySQL', 'WordPress', 'HTML'},
#  {'C',
#   'C++',
#   'Flask',
#   'MySQL',
#   'NumPy',
#   'Opencv',
#   'Pandas',
#   'PyTorch',
#   'Python',
#   'TensorFlow'},
#  {'HTML', 'CSS'},
#  {'Laravel'},
#  {'Python'},
#  {'TensorFlow'},
#  {'HTML', 'WordPress', 'CSS'},
#  {'C++', 'TensorFlow', 'Pandas', 'NumPy', 'Python'},
#  {'PHP', 'WordPress'},
#  {'Python', 'SQL'},
#  {'jQuery', 'WordPress'},
#  {'Python'},
#  {'WordPress'},
#  {'PHP', 'Composer', 'JavaScript', 'WordPress', 'Laravel', 'MySQL', 'HTML'},
#  {'AWS',
#   'Azure',
#   'CSS',
#   'Go',
#   'JavaScript',
#   'Linux',
#   'PHP',
#   'Python',
#   'Visual Studio',
#   'WordPress'},
#  {'WordPress'},
#  {'.NET',
#   'AWS',
#   'Angular',
#   'Azure',
#   'C#',
#   'CSS',
#   'Django',
#   'Docker',
#   'Google Cloud',
#   'JavaScript',
#   'Kubernetes',
#   'Laravel',
#   'MariaDB',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'React',
#   'Redis',
#   'SQL',
#   'TypeScript',
#   'WordPress'},
#  {'Python', 'SQL'},
#  {'Git', 'AWS'},
#  {'WordPress'},
#  {'AWS',
#   'Azure',
#   'Bash',
#   'Cloudflare',
#   'Firebase',
#   'Go',
#   'Google Cloud',
#   'HTML',
#   'Java',
#   'JavaScript',
#   'Kubernetes',
#   'Linux',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'SQL',
#   'Terraform',
#   'VMware',
#   'jQuery'},
#  {'HTML'},
#  {'Composer', 'WordPress'},
#  {'AWS', 'MongoDB', 'Oracle', 'SQL', 'Azure'},
#  {'C',
#   'Firebase',
#   'Git',
#   'Java',
#   'JavaScript',
#   'MySQL',
#   'PHP',
#   'SQLite',
#   'Swift',
#   'iOS'},
#  {'CSS', 'WordPress', '.NET', 'Linux'},
#  {'PHP', 'WordPress', 'CSS'},
#  {'AWS', 'Google Cloud', 'iOS', 'Azure', 'Linux'},
#  {'Laravel'},
#  {'jQuery', 'Python', 'Heroku', 'Django'},
#  {'WordPress'},
#  {'Python'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'WordPress', 'HTML'},
#  {'iOS', 'Linux'},
#  {'HTML', 'iOS', 'WordPress', 'CSS'},
#  {'C',
#   'Linux',
#   'NumPy',
#   'Pandas',
#   'PostgreSQL',
#   'Python',
#   'Redis',
#   'SQL',
#   'SQLite'},
#  {'AWS',
#   'CSS',
#   'Django',
#   'Docker',
#   'FastAPI',
#   'Flask',
#   'JavaScript',
#   'Pandas',
#   'Python',
#   'React',
#   'React Native',
#   'TensorFlow'},
#  {'CSS'},
#  {'CSS',
#   'Express',
#   'HTML',
#   'JavaScript',
#   'Laravel',
#   'React',
#   'WordPress',
#   'iOS'},
#  {'Python', 'SQL'},
#  {'HTML', 'WordPress', 'CSS'},
#  {'PHP', 'CSS', 'JavaScript', 'MySQL', 'HTML'},
#  {'WordPress'},
#  {'WordPress'},
#  {'.NET',
#   'C',
#   'C++',
#   'CSS',
#   'Composer',
#   'Flutter',
#   'HTML',
#   'Java',
#   'Kotlin',
#   'Laravel',
#   'MySQL',
#   'PHP',
#   'React',
#   'React Native',
#   'Swift',
#   'WordPress',
#   'iOS'},
#  {'WordPress', 'Flutter'},
#  {'SQL'},
#  {'Swift'},
#  {'PyTorch', 'TensorFlow'},
#  {'HTML', 'CSS'},
#  {'Azure', 'AWS'},
#  {'WordPress'},
#  {'Angular', 'React', 'Express'},
#  {'.NET',
#   'C#',
#   'JavaScript',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'SQL',
#   'SQLite'},
#  {'Opencv', 'PyTorch', 'TensorFlow', 'SQL', 'Pandas', 'NumPy', 'Python'},
#  {'Composer', 'HTML', 'WordPress'},
#  {'CSS'},
#  {'WordPress', 'Linux'},
#  {'Python', 'C++', 'C#'},
#  {'PHP', 'AWS', 'Oracle', 'MySQL', 'Linux'},
#  {'AWS',
#   'Cloudflare',
#   'Django',
#   'Kafka',
#   'Linux',
#   'MariaDB',
#   'MySQL',
#   'PostgreSQL',
#   'Python',
#   'Redis',
#   'WordPress'},
#  {'VMware', 'Linux', 'Oracle'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'MySQL', 'WordPress', 'HTML'},
#  {'PHP', 'CSS', 'C++', 'JavaScript', 'WordPress', 'HTML'},
#  {'SQLite', 'MySQL', 'TensorFlow', 'SQL', 'Azure', 'Pandas', 'NumPy', 'Python'},
#  {'AWS',
#   'Angular',
#   'AngularJS',
#   'CSS',
#   'Firebase',
#   'HTML',
#   'Heroku',
#   'JavaScript',
#   'Laravel',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'React',
#   'TypeScript',
#   'jQuery'},
#  {'JavaScript'},
#  {'Azure', '.NET'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'Docker',
#   'Google Cloud',
#   'Kubernetes',
#   'Swift',
#   'Terraform',
#   'Travis'},
#  {'Laravel', 'WordPress'},
#  {'iOS'},
#  {'FastAPI',
#   'Flask',
#   'Flutter',
#   'JavaScript',
#   'PHP',
#   'PyTorch',
#   'Python',
#   'React',
#   'Svelte',
#   'WordPress'},
#  {'WordPress'},
#  {'CSS', 'jQuery', 'JavaScript', 'WordPress', 'HTML'},
#  {'Java'},
#  {'AWS',
#   'Azure',
#   'Bash',
#   'CSS',
#   'Docker',
#   'HTML',
#   'JavaScript',
#   'Kubernetes',
#   'Linux',
#   'MariaDB',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'PowerShell',
#   'WordPress'},
#  {'MySQL', 'SQL'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'Angular', 'WordPress', 'iOS', 'MySQL'},
#  {'PHP', 'Django', 'JavaScript', 'WordPress', 'Python', 'HTML'},
#  {'PHP', 'WordPress'},
#  {'WordPress'},
#  {'Composer', 'Go', 'WordPress'},
#  {'Angular',
#   'C',
#   'C++',
#   'CSS',
#   'Django',
#   'Flutter',
#   'Git',
#   'HTML',
#   'Java',
#   'JavaScript',
#   'Kotlin',
#   'MongoDB',
#   'MySQL',
#   'Oracle',
#   'PHP',
#   'Python',
#   'React',
#   'SQL',
#   'SQLite',
#   'Swift',
#   'WordPress',
#   'jQuery',
#   'npm'},
#  {'SQL', 'Oracle'},
#  {'PHP', 'jQuery', 'Go', 'WordPress', 'MySQL'},
#  {'Python', 'Flask', 'Django'},
#  {'Google Cloud', 'Django', 'AWS', 'Flask', 'Pandas', 'Python'},
#  {'Ansible',
#   'Azure',
#   'Google Cloud',
#   'Java',
#   'Kubernetes',
#   'Linux',
#   'MySQL',
#   'PowerShell',
#   'Python',
#   'Terraform',
#   'VMware'},
#  {'iOS'},
#  {'CSS',
#   'HTML',
#   'JavaScript',
#   'MySQL',
#   'PHP',
#   'SQL',
#   'TypeScript',
#   'WordPress',
#   'jQuery'},
#  {'AWS',
#   'Django',
#   'Docker',
#   'FastAPI',
#   'Flask',
#   'Heroku',
#   'MySQL',
#   'PostgreSQL',
#   'Python'},
#  {'Go', 'SQL'},
#  {'AWS',
#   'CSS',
#   'Google Cloud',
#   'JavaScript',
#   'Laravel',
#   'MySQL',
#   'PHP',
#   'WordPress',
#   'jQuery'},
#  {'.NET',
#   'CSS',
#   'HTML',
#   'JavaScript',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'SQL',
#   'jQuery'},
#  {'MySQL', 'Linux', 'Oracle'},
#  {'Python', 'Azure', 'SQL', 'AWS'},
#  {'iOS'},
#  {'Go', 'WordPress'},
#  {'AWS',
#   'Bash',
#   'C',
#   'C#',
#   'C++',
#   'CSS',
#   'Django',
#   'HTML',
#   'Linux',
#   'NumPy',
#   'Pandas',
#   'Python',
#   'SQL'},
#  {'jQuery', 'JavaScript', 'WordPress', 'PHP'},
#  {'PHP', 'CSS', 'WordPress', 'Cloudflare', 'HTML'},
#  {'AWS', 'Oracle', 'SQL', 'MySQL', 'Linux'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'Bash',
#   'Docker',
#   'Git',
#   'Google Cloud',
#   'Kubernetes',
#   'Linux',
#   'Python',
#   'Terraform',
#   'Travis',
#   'WordPress'},
#  {'CSS', 'AWS', 'JavaScript', 'WordPress', 'iOS', 'HTML'},
#  {'MySQL', 'Firebase'},
#  {'MySQL', 'Linux', 'Ansible'},
#  {'Git', 'AWS', 'Python', 'Elasticsearch', 'Docker'},
#  {'JavaScript', 'SQL'},
#  {'.NET',
#   'Angular',
#   'C#',
#   'CSS',
#   'Composer',
#   'HTML',
#   'Java',
#   'JavaScript',
#   'Laravel',
#   'PHP',
#   'Python',
#   'React',
#   'WordPress',
#   'jQuery'},
#  {'CSS', 'JavaScript', 'Go', 'WordPress', 'HTML'},
#  {'Go'},
#  {'PHP', 'Laravel', 'WordPress', 'iOS'},
#  {'CSS',
#   'HTML',
#   'Java',
#   'MySQL',
#   'Oracle',
#   'PHP',
#   'SQL',
#   'WordPress',
#   'jQuery'},
#  {'Python'},
#  {'AWS',
#   'Cloudflare',
#   'Docker',
#   'Elasticsearch',
#   'Linux',
#   'Ruby',
#   'VMware',
#   'WordPress'},
#  {'AWS',
#   'Ansible',
#   'Azure',
#   'Docker',
#   'Linux',
#   'MySQL',
#   'Python',
#   'VMware',
#   'WordPress'},
#  {'WordPress'},
#  {'Django', 'AWS', 'Go', 'MySQL', 'Oracle', 'SQL', 'Azure', 'Python'},
#  {'Azure',
#   'Docker',
#   'Google Cloud',
#   'Kubernetes',
#   'Swift',
#   'Terraform',
#   'VMware'},
#  {'Angular',
#   'Git',
#   'HTML',
#   'JavaScript',
#   'MySQL',
#   'PHP',
#   'Python',
#   'WordPress',
#   'jQuery'},
#  {'PowerShell'},
#  {'Firebase', 'Google Cloud', 'Go', 'PostgreSQL', 'MySQL', 'MongoDB', 'Python'},
#  {'Swift', 'SQL'},
#  {'WordPress'},
#  {'AWS',
#   'Azure',
#   'Google Cloud',
#   'Linux',
#   'MariaDB',
#   'MySQL',
#   'Oracle',
#   'PHP',
#   'VMware',
#   'WordPress'},
#  {'C'},
#  {'AWS',
#   'Ansible',
#   'Docker',
#   'Git',
#   'Linux',
#   'MariaDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'VMware'},
#  {'AWS', 'WordPress', 'Cloudflare', 'Linux'},
#  {'CSS', 'jQuery', 'JavaScript', 'Go', 'HTML'},
#  {'WordPress'},
#  {'PHP', 'JavaScript', 'WordPress', 'Linux'},
#  {'HTML', 'WordPress'},
#  {'AWS', 'Kubernetes', 'Docker', 'Terraform'},
#  {'PHP', 'Python'},
#  {'PHP', 'CSS', 'jQuery', 'WordPress', 'HTML'},
#  {'AWS',
#   'Bash',
#   'Django',
#   'Docker',
#   'Go',
#   'Kubernetes',
#   'Laravel',
#   'Linux',
#   'Python',
#   'React',
#   'Terraform',
#   'TypeScript'},
#  {'Go', 'AWS'},
#  {'WordPress'},
#  {'PHP', 'Django', 'JavaScript', 'Java', 'SQL', 'Pandas', 'Python'},
#  {'PHP', 'CSS', 'Angular', 'WordPress', 'Java', 'Cloudflare', 'HTML'},
#  {'WordPress'},
#  {'Azure', 'SQL', 'C#'},
#  {'HTML', 'Go', 'WordPress'},
#  {'CSS', 'AWS', 'MySQL', '.NET', 'Laravel', 'HTML', 'Linux'},
#  {'Azure', 'SQL'},
#  {'CSS', 'Composer', 'WordPress', 'Cloudflare', 'HTML'},
#  {'.NET',
#   'AWS',
#   'Angular',
#   'C#',
#   'Google Cloud',
#   'Laravel',
#   'Linux',
#   'MySQL',
#   'Oracle',
#   'PHP',
#   'Pandas',
#   'Python',
#   'SQL',
#   'WordPress'},
#  {'SQL'},
#  {'SQL', 'Firebase', 'WordPress'},
#  {'PHP', 'HTML', 'Laravel', 'WordPress'},
#  {'Swift'},
#  {'jQuery', 'JavaScript', 'HTML'},
#  {'AWS',
#   'Docker',
#   'Elasticsearch',
#   'Google Cloud',
#   'JavaScript',
#   'Kubernetes',
#   'MongoDB',
#   'Python',
#   'Redis'},
#  {'VMware', 'Terraform', 'Ansible', 'Python', 'Kubernetes', 'Docker'},
#  {'CSS',
#   'HTML',
#   'JavaScript',
#   'MySQL',
#   'PostgreSQL',
#   'Python',
#   'SQL',
#   'jQuery'},
#  {'PHP', 'WordPress'},
#  {'PyTorch'},
#  {'AWS'},
#  {'PHP', 'JavaScript', 'WordPress', 'SQL', 'Linux'},
#  {'AWS',
#   'Docker',
#   'Express',
#   'Flask',
#   'Heroku',
#   'MySQL',
#   'PostgreSQL',
#   'Python',
#   'React',
#   'Vite',
#   'Webpack'},
#  {'WordPress'},
#  {'SQL'},
#  {'AWS',
#   'C',
#   'C#',
#   'Google Cloud',
#   'Kubernetes',
#   'Linux',
#   'MariaDB',
#   'PHP',
#   'Python',
#   'Terraform',
#   'WordPress'},
#  {'Oracle'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'WordPress', 'HTML'},
#  {'Composer', 'WordPress'},
#  {'Git', 'VMware', 'Ansible', 'Docker'},
#  {'AWS',
#   'Azure',
#   'Git',
#   'Google Cloud',
#   'Java',
#   'Kotlin',
#   'Linux',
#   'MariaDB',
#   'MySQL',
#   'PHP',
#   'PostgreSQL',
#   'Python',
#   'Redis',
#   'Swift'},
#  {'PHP', 'CSS', 'jQuery', 'JavaScript', 'MySQL', 'WordPress', 'HTML'},
#  {'Swift'},
#  {'WordPress'},
#  {'Azure'},
#  {'WordPress', 'Linux'},
#  {'Azure', 'AWS'},
#  {'PHP', 'Google Cloud', 'JavaScript', 'WordPress', 'AngularJS'},
#  {'Azure', 'PowerShell'},
#  {'PowerShell'},
#  {'Angular',
#   'CSS',
#   'JavaScript',
#   'Laravel',
#   'MySQL',
#   'PHP',
#   'React',
#   'TypeScript',
#   'WordPress',
#   'iOS',
#   'jQuery'},
#  {'WordPress'},
#  {'WordPress', 'AWS', 'Express'},
#  {'HTML', 'CSS'},
#  {'AWS'},
#  {'VMware', 'Azure'},
#  {'Azure'},
#  {'SQL'},
#  {'C++'},
#  {'CSS',
#   'Django',
#   'Express',
#   'Flutter',
#   'HTML',
#   'JavaScript',
#   'Kotlin',
#   'Laravel',
#   'MongoDB',
#   'MySQL',
#   'PHP',
#   'React',
#   'React Native',
#   'Swift',
#   'iOS'},
#  {'PHP', 'WordPress'},
#  {'PostgreSQL', 'Azure', 'SQL', 'PowerShell', 'MySQL'},
#  {'Python', 'WordPress'},
#  {'VMware', 'SQL'},
#  {'Azure'},
#  {'Kubernetes', 'SQL', '.NET', 'Docker'},
#  {'Azure'},
#  {'.NET'}]

# %%
def plot_skills(count_frame):
    plt.figure(figsize=(10, 10))
    sns.barplot(x=count_frame.values, y=count_frame.index, palette="viridis")
    plt.title("Distribution of Skills in the Dataset")
    plt.xlabel("Count")
    plt.ylabel("Skills")
    plt.show()
